# %%
from PIL import Image
import h5py
# import anubisPlotUtils as anPlot
import json
import numpy as np
import os
import hist as hi
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
matplotlib.use('TkAgg')  # or 'Qt5Agg', 'GTK3Agg', etc.
import mplhep as hep
hep.style.use([hep.style.ATLAS])
import sys
# import ANUBIS_triggered_functions as ANT
import pandas as pd
import matplotlib.backends.backend_pdf
from matplotlib.ticker import MultipleLocator
import plotly
import plotly.graph_objs as go
import plotly.express as px
from functools import reduce
import matplotlib.pyplot as plt
import numpy as np
# from scipy.stats import normpip install pillow
sys.path.insert(1, 'Osiris Temp\processing\python')
import rawFileReader
import csv
from itertools import groupby
import math

import importlib
# %matplotlib inline
# Out:
# <>:26: SyntaxWarning: invalid escape sequence '\p'
# <>:26: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Peter\AppData\Local\Temp\ipykernel_11328\922193874.py:26: SyntaxWarning: invalid escape sequence '\p'
#   sys.path.insert(1, 'Osiris Temp\processing\python')

# %%
class rpcHit():
    def __init__(self, channel, time, eta, event_num, rpc):
        self.rpc = rpc
        self.time = time
        self.channel = channel
        self.eta = eta
        self.event_num = event_num

    def __str__(self):
        return f"rpcHit(channel={self.channel}, time={self.time}, eta={self.eta}, event_num={self.event_num}, rpc={self.rpc})"

class rpcCoincidence():
    def __init__(self, event_num, time_bin, hits):
        self.event_num = event_num
        self.time_bin = time_bin
        self.hits = hits

    def __str__(self):
        return f"rpcCoincidence(event_num={self.event_num}, time_bin={self.time_bin}, hits={self.hits})"


def tdcChanToRPCHit(word, tdc, event_num):
    tdcChannel = (word >> 24) & 0x7f
    tdcHitTime = word & 0xfffff
    eta = False
    rpcChan = -1
    if tdc == 0:
        if tdcChannel < 32:
            rpcChan = tdcChannel
            eta = True
            rpc = 0
        elif tdcChannel < 96:
            rpcChan = tdcChannel - 32
            eta = False
            rpc = 0
        else:
            rpcChan = tdcChannel - 96
            eta = True
            rpc = 1
    elif tdc == 1:
        if tdcChannel < 64:
            rpcChan = tdcChannel
            eta = False
            rpc = 1
        elif tdcChannel < 96:
            rpcChan = tdcChannel - 64
            eta = True
            rpc = 2
        else:
            rpcChan = tdcChannel - 96
            eta = False
            rpc = 2
    elif tdc == 2:
        if tdcChannel < 32:
            rpcChan = tdcChannel + 32
            eta = False
            rpc = 2
        elif tdcChannel < 64:
            rpcChan = tdcChannel - 32
            eta = True
            rpc = 3
        elif tdcChannel < 128:
            rpcChan = tdcChannel - 64
            eta = False
            rpc = 3
    elif tdc == 3:
        if tdcChannel < 32:
            rpcChan = tdcChannel
            eta = True
            rpc = 4
        elif tdcChannel < 96:
            rpcChan = tdcChannel - 32
            eta = False
            rpc = 4
        else:
            rpcChan = tdcChannel - 96
            eta = True
            rpc = 5
    elif tdc == 4:
        rpcChan = tdcChannel
        eta = False
        rpc = 5
    return rpc, rpcHit(rpcChan, tdcHitTime * 0.8, eta, event_num, rpc)
def Unpack_event(eventList, processedEvents):
    allEtaHits = [[] for rpc in range(6)]
    allPhiHits = [[] for rpc in range(6)]
    for event_num, event in enumerate(eventList):
        etaHits = [[] for rpc in range(6)]
        phiHits = [[] for rpc in range(6)]
        for i in range(5):
            for word in event.tdcEvents[i].words:
                rpc, thisHit = tdcChanToRPCHit(word, i, processedEvents - len(eventList) + event_num + 1)
                if thisHit.eta:
                    etaHits[thisHit.rpc].append(thisHit)
                else:
                    phiHits[thisHit.rpc].append(thisHit)
        for rpc in range(6):
            allEtaHits[rpc].extend(etaHits[rpc])
            allPhiHits[rpc].extend(phiHits[rpc])
    return allEtaHits, allPhiHits
def FindCoincidentHits(etaHits, phiHits, time_window):
    channels = []
    
    # Combine etaHits and phiHits from all RPCs
    for RPC in range(6):
        channels += etaHits[RPC]
        channels += phiHits[RPC]

    # Sort events by event number and then by time within each event
    event_sorted = sorted(channels, key=lambda rpcHit: (rpcHit.event_num, rpcHit.time))
    
    # Group by event number
    grouped_and_sorted = {key: list(group) 
                          for key, group in groupby(event_sorted, lambda rpcHit: rpcHit.event_num)}
    
    coincident_hits = []
    
    for event_num, hits in grouped_and_sorted.items():
        temp_hits = []
        for i in range(len(hits) - 1):
            if abs(hits[i+1].time - hits[i].time) <= time_window:
                temp_hits.append(hits[i])
                temp_hits.append(hits[i+1])
        
        if temp_hits:
            time_bin = min(hit.time for hit in temp_hits)
            unique_hits = list({(hit.channel, hit.time, hit.eta, hit.event_num, hit.rpc): hit for hit in temp_hits}.values())
            coincident_hits.append([
                event_num,
                time_bin,
                [[hit.rpc, hit.channel, hit.time, hit.eta] for hit in unique_hits]
            ])

    return coincident_hits
def cluster(coincident_hits):
    coincident_hits_clustered = []

    for coincidence_event in coincident_hits:

        coincident_event_clustered = [coincidence_event[0], coincidence_event[1], []]

        hit_locations = coincidence_event[2]
        phi_locations = [x for x in hit_locations if x[3] == False]
        eta_locations = [x for x in hit_locations if x[3] == True]

        phi_locations = sorted(phi_locations, key=lambda x: x[1])
        eta_locations = sorted(eta_locations, key=lambda x: x[1])

        for RPC in range(6):
            rpc_phi_clusters = []
            rpc_eta_clusters = []

            i = 0
            for index, hit in enumerate([x for x in phi_locations if x[0] == RPC]):
                if index == 0:
                    previous_element = hit[1]
                    rpc_phi_clusters.append([hit])
                else:
                    if abs(hit[1] - previous_element) > 1:
                        rpc_phi_clusters.append([hit])
                        i += 1
                    else:
                        rpc_phi_clusters[i].append(hit)
                    previous_element = hit[1]

            j = 0
            for index, hit in enumerate([x for x in eta_locations if x[0] == RPC]):
                if index == 0:
                    previous_element = hit[1]
                    rpc_eta_clusters.append([hit])
                else:
                    if abs(hit[1] - previous_element) > 1:
                        rpc_eta_clusters.append([hit])
                        j += 1
                    else:
                        rpc_eta_clusters[j].append(hit)
                    previous_element = hit[1]

            rpc_combined = [rpc_phi_clusters, rpc_eta_clusters]

            coincident_event_clustered[2].append(rpc_combined)

        coincident_hits_clustered.append(coincident_event_clustered)

    return coincident_hits_clustered
def check_event_attributes(event,min_chamber_number,min_RPC_number):
    #Used in filter_events() function to decide whether or not to save an event as described by the user's inputs.

    # event = ['Event x',TIMEBIN, [[[RPC1_PHI_CLUSTERS],[RPC1_ETA_CLUSTERS]],[[...],[...]],...]

    RPC_counter = 0
    chamber_counter = 0
    condition_1 = False
    condition_2 = False
    condition_3 = False

    for RPC in range(6):
        if RPC<3:
            #Checking triplet layer.
            if event[2][RPC][0] and event[2][RPC][1]:
                #Reqiure       phi^              and               eta^       strips to go off
                RPC_counter+=1 
                #If RPC has two eta and phi strips going off then consider it "hit"
                if not condition_1:
                    #Count triplet chamber being hit.
                    chamber_counter+=1
                    condition_1 = True
        elif RPC == 3:
            #Singlet layer
            if event[2][RPC][0] and event[2][RPC][1]:
                RPC_counter+=1
                if not condition_2:
                    chamber_counter+=1
                    condition_2 = True
        else:
            #Doublet layer
            if event[2][RPC][0] and event[2][RPC][1]:
                RPC_counter+=1
                if not condition_3:
                    chamber_counter+=1
                    condition_3 = True

    return RPC_counter >= min_RPC_number and chamber_counter >= min_chamber_number
def filter_events(events,min_chamber_number,min_RPC_number):
    #Initiliase array of filtered events
    filtered_events = []

    for event in events:
        if check_event_attributes(event,min_chamber_number,min_RPC_number):
            filtered_events.append(event)

    print(f"Number of events in filter = {len(filtered_events)}")
    
    return filtered_events
def generate_hit_coords_combo_Chi2(coords, RPC_heights, max_length=None, exact_length=False, combinations=None, hit_coords=None, depth=0):
    if combinations is None:
        combinations = []
    if hit_coords is None:
        hit_coords = []
    if max_length is None:
        max_length = len(coords)

    # Base case: If we've reached the end of the coords or the length condition is met
    if depth == len(coords) or len(hit_coords) == max_length:
        if not exact_length or len(hit_coords) == max_length:
            combinations.append(hit_coords.copy())
        return combinations

    # Extract x and y values for the current depth
    x_values = coords[depth][0]
    y_values = coords[depth][1]

    # If there are no x or y values at this depth, move to the next depth
    if not x_values or not y_values:
        return generate_hit_coords_combo_Chi2(coords, RPC_heights, max_length, exact_length, combinations, hit_coords, depth + 1)

    # Iterate over all combinations of x and y values
    for x in x_values:
        for y in y_values:
            if x is not None and y is not None and isinstance(x[0], (int, float)) and isinstance(y[0], (int, float)):
                hit_coords.append([x, y, RPC_heights[depth]])
                generate_hit_coords_combo_Chi2(coords, RPC_heights, max_length, exact_length, combinations, hit_coords, depth + 1)
                hit_coords.pop()

    return combinations
def extract_DT_DZ_Chi2(coords):

    #coords = [[[x0,var,time],[y0,var],z0],[[x1,var,time],[y1,var],z1],...,[[x5,var,time],[y5,var],z5]]

    times = [[RPC,x[0][2]] for RPC, x in enumerate(coords) if isinstance(x[2], (float, int))]

    #Should already be sorted, but just in case.
    #Sort times by RPC, with RPC at lowest height at first entry.

    if len(times) > 1:

        times_sorted = sorted(times, key=lambda x: x[0])

        #print(times_sorted)

        dT = times_sorted[-1][1]-times_sorted[0][1]
        #if dT>0 this implies the particles hit the higher RPC after the lower one, so the particle is travelling upwards here.
        #Vice-versa for dT < 0 

        RPC_heights = [0.6,1.8,3.0,61.8,121.8,123] #Heights of middle point of each RPC, measured from the bottom of the Triplet Low RPC. Units are cm.

        first_RPC = times_sorted[0][0]
        last_RPC = times_sorted[-1][0]

        dZ = RPC_heights[last_RPC] - RPC_heights[first_RPC]
    
        return dT, dZ
    else:
        pass
def fit_event_chi2(coordinates_with_error):
    #Coordinates = [[[x0,var,time],[y0,var],z0],[[x1,var,time],[y1,var],z1],...,[[x5,var,time],[y5,var],z5]]
    #Z coordinate given by height of relevant RPC.
    #Using SVD

    # Calculate dT for event, in ns
    dT, dZ = extract_DT_DZ_Chi2(coordinates_with_error)
    
    coordinates = []

    for coords in coordinates_with_error:
        coordinates.append([coords[0][0],coords[1][0],coords[2]])

    centroid = np.mean(coordinates, axis=0)
    subtracted = coordinates-centroid

    # performing SVD
    _, _, V = np.linalg.svd(subtracted)
    
    # find the direction vector (which is the right singular vector corresponding to the largest singular value)
    direction = V[0, :]

    # A line is defined by the average and its direction
    p0 = centroid
    d = direction

    #Work out Chi2. Minimise this to find best fit (from possible combos)

    Chi2 = 0

    i = 0 

    for point in coordinates_with_error:
        
        i+=2
        
        z = point[2]
        x = point[0][0]
        y = point[1][0]
        x_var = point[0][1]
        y_var = point[1][1]

        z_0 = centroid[2]

        # t = (z-z_0)/d_z

        t = (z-z_0)/d[2]

        # Find expected (x,y) coordinates at that height.

        x_traj = centroid[0] + t*d[0]
        y_traj = centroid[1] + t*d[1]

        Chi2_x = (x-x_traj)**2 / x_var
        Chi2_y = (y-y_traj)**2 / y_var

        Chi2+= Chi2_x
        Chi2+= Chi2_y

    # i is number of fitted points. There are 4 fitted paramters, 2 for each x and y. 
    doF = i - 4

    Chi2 = Chi2/ doF

    return p0, d, Chi2, coordinates, dT, dZ
def extract_coords_timed_Chi2(event,max_cluster_size):

    #This function converts spatially clusters in RPCs into x and y coordinates (z given by RPC number)
    # event = ['Event x',TIMEBIN, [[[RPC1_PHI_CLUSTERS],[RPC1_ETA_CLUSTERS]],[[...],[...]],...]

    #Extract x and y coords of cluster in event
    distance_per_phi_channel = 2.7625 #cm
    distance_per_eta_channel = 2.9844 #cm
    
    coords = []

    for RPC in range(6):
        
        x_clusters = [x for x in event[2][RPC][0] if len(x)<=max_cluster_size] #phi direction
        y_clusters = [y for y in event[2][RPC][1] if len(y)<=max_cluster_size] #eta direction

        #Finding size of largest cluster, consider coordinates bad if largest cluster is larger than 6.
        x_clusters_lengths = [len(x) for x in event[2][RPC][0]]
        y_clusters_lengths = [len(y) for y in event[2][RPC][1]]

        max_length = max(max(x_clusters_lengths, default=0), max(y_clusters_lengths, default=0))

        x_coords = []
        y_coords = []
        
        for x_cluster in x_clusters:
            # Extract phi channels and times from the cluster
            phi_channels = [x[1] for x in x_cluster]
            phi_times = [t[2] for t in x_cluster]

            # Convert the channel number into a measurement along the RPC
            x_values = [(phi_channel + 0.5) * distance_per_phi_channel for phi_channel in phi_channels]

            # Variance in x coord
            x_var = (1 * distance_per_phi_channel) ** 2 / 12

            # Find the index of the minimum time
            min_time_index = phi_times.index(min(phi_times))

            # Append the x value corresponding to the minimum time
            x_coords.append([x_values[min_time_index], x_var, min(phi_times)])

        for y_cluster in y_clusters:
            #y_cluster = [[RPC,CHANNEL,TIME,'eta'],...]
            eta_channels_corrected = [31-y[1] for y in y_cluster] #corrected for labelling from 0 to 31.
            eta_times = [t[2] for t in y_cluster]
            y_values = [(channel_num+0.5)*distance_per_eta_channel for channel_num in eta_channels_corrected]
            
            y_var = (1*distance_per_eta_channel)**2 /12
            
            # Find the index of the minimum time
            min_time_index = eta_times.index(min(eta_times))
            
            y_coords.append([y_values[min_time_index],y_var,min(eta_times)])

        if x_coords and y_coords:

            coords.append([x_coords, y_coords])

        else:
            coords.append([[],[],"N"])

    #[x_coords] = [[x,err_x,x_time],...]
    
    #RPC_coords = [x_coords,y_coords]

    #coords = [[RPC1_coords],[RPC2_coords],[RPC3_coords],...]
    return coords
def reconstruct_timed_Chi2_ByRPC(event,max_cluster_size, RPC_excluded):

    #timed tag indicates that timing information from RPC is used to determine direction of vertical transversal of "particle" in the event.

    max_Chi2 = 10

    # event = ['Event x',TIMEBIN, [[[RPC1_PHI_CLUSTERS],[RPC1_ETA_CLUSTERS]],[[...],[...]],...]
    RPC_heights = [0.6,1.8,3.0,61.8,121.8,123] #Heights of middle point of each RPC, measured from the bottom of the Triplet Low RPC. Units are cm.


    #Extract x and y coords of cluster in event
    coords = extract_coords_timed_Chi2(event,max_cluster_size)

     # Filter out coords of RPC under test 

    test_coords = coords[RPC_excluded]

    coords[RPC_excluded] = [[],[],"N"] 

    # Count the number of empty RPCs
    empty_RPC_count = sum(1 for item in coords if item == [[], [],'N'])

    # If less than 3 elements of coords are occupied, exit the function
    if empty_RPC_count > 3:
        #print("Failed to reconstruct, not enough coords")
        return None  # Exit the function
    
    cross_chamberness = 0

    if coords[0] != [[], [], 'N'] or coords[1] != [[], [], 'N'] or coords[2] != [[], [], 'N']:
        cross_chamberness += 1

    if coords[3] != [[], [], 'N']:
        cross_chamberness += 1

    if coords[4] != [[], [], 'N'] or coords[5] != [[], [], 'N']:
        cross_chamberness += 1

    if cross_chamberness < 2:
        #print("Failed to reconstruct, too few chambers")
        return None

    #ITERATING OVER EVERY POSSIBLE COMBINATION OF x,y,z over all 3 RPCs (limited to one x,y per RPC).
    #Doesn't look particularly nice, but there are not many coordinates to loop over usually....

    combinations = generate_hit_coords_combo_Chi2(coords,RPC_heights)

    #Now for each combo in combinations, attempt to reconstruct a path. See which one gives the best trajectory.

    #If success, print parameters of fitting function.
    #If fail, print reconstruction failed.

    Chi2_current = np.inf
    optimised_coords = None
    optimised_d= None
    optimised_centroid= None
    dT = np.inf

    for ind,combo in enumerate(combinations):

        centroid, d, Chi2, coordinates, delta_T, delta_Z= fit_event_chi2(combo)
        if Chi2 < Chi2_current:

            # If new fit is better than old then replace old fit properties.
            dZ = delta_Z 
            dT = delta_T
            Chi2_current = Chi2
            optimised_centroid = centroid
            optimised_d = d
            optimised_coords = coordinates

    #if dT>0 this implies the particles hit the higher RPC after the lower one, so the particle is travelling upwards here.
    #Vice-versa for dT < 0.

    #dT = 0 case?

    if dT != np.inf:

        if dT > 0:
            if optimised_d[2] < 0:
                optimised_d = np.multiply(optimised_d,-1)
        else:
            if optimised_d[2] > 0:
                optimised_d = np.multiply(optimised_d,-1)

        if Chi2_current<max_Chi2:
            return optimised_centroid, optimised_d, optimised_coords, combinations, Chi2_current, dT, dZ, test_coords

    else:
        #print("Failed to reconstruct, Chi2 too large")
        #return optimised_centroid, optimised_d, optimised_coords, combinations, residuals_current
        return None
def check_event_attributes_by_RPC(event, min_chamber_number, min_RPC_number, RPC_excluded):
    # Used in filter_events() function to decide whether or not to save an event as described by the user's inputs.
    # The user selects an RPC to exclude from the filter.
    # e.g. say we want to exclude RPC 4 and the user selects a min_RPC_number of 4.
    # The function will check if the event has at least 4 RPCs hit.

    # USING ONLY ETA FILTER HERE SINCE THIS IS WHAT TRIGGERS THE CHANNEL!

    # event = ['Event x', TIMEBIN, [[[RPC1_PHI_CLUSTERS],[RPC1_ETA_CLUSTERS]],[[...],[...]],...]

    RPC_counter = 0
    chamber_counter = 0
    condition_1 = False
    condition_2 = False
    condition_3 = False

    # Check if any of the excluded RPCs have ETA clusters
    # for excluded_RPC in RPC_excluded:
    if event[2][RPC_excluded][1] != []:
        return False

    for RPC in range(6):
        if RPC != RPC_excluded:
            # If the RPC is not excluded, we check for ETA clusters.
            if event[2][RPC][1]:
                RPC_counter += 1

                if RPC < 3:
                    # Checking triplet layer.
                    if not condition_1:
                        chamber_counter += 1
                        condition_1 = True
                elif RPC == 3:
                    # Checking singlet layer.
                    if not condition_2:
                        chamber_counter += 1
                        condition_2 = True
                else:
                    # Checking doublet layer.
                    if not condition_3:
                        chamber_counter += 1
                        condition_3 = True

    return RPC_counter >= min_RPC_number and chamber_counter >= min_chamber_number
def filter_events_by_RPC(events,min_chamber_number,min_RPC_number,RPC_excluded):
    #Initiliase array of filtered events
    filtered_events = []

    for event in events:
        if check_event_attributes_by_RPC(event,min_chamber_number,min_RPC_number,RPC_excluded):
            filtered_events.append(event)
        else :
            event[2][RPC_excluded][1] = []
            event[2][RPC_excluded][0] = []
            filtered_events.append(event)
                

   # print(f"Number of events in filter = {len(filtered_events)}")
    
    return filtered_events
def reconstruct_timed_Chi2(event,max_cluster_size, max_length=None, exact_length=False):

    #timed tag indicates that timing information from RPC is used to determine direction of vertical transversal of "particle" in the event.

    max_Chi2 = 10

    # event = ['Event x',TIMEBIN, [[[RPC1_PHI_CLUSTERS],[RPC1_ETA_CLUSTERS]],[[...],[...]],...]
    RPC_heights = [0.6,1.8,3.0,61.8,121.8,123] #Heights of middle point of each RPC, measured from the bottom of the Triplet Low RPC. Units are cm.

    #Extract x and y coords of cluster in event

    coords = extract_coords_timed_Chi2(event,max_cluster_size)

    # Count the number of empty RPCs
    empty_RPC_count = sum(1 for item in coords if item == [[], [],'N'])

    # If less than 3 elements of coords are occupied, exit the function
    if empty_RPC_count > 3:
        #print("Failed to reconstruct, not enough coords")
        return None  # Exit the function
    
    #NEED TO CHECK IF STILL CROSS CHAMBER! 

    cross_chamberness = 0

    if coords[0] != [[], [], 'N'] or coords[1] != [[], [], 'N'] or coords[2] != [[], [], 'N']:
        cross_chamberness += 1

    if coords[3] != [[], [], 'N']:
        cross_chamberness += 1

    if coords[4] != [[], [], 'N'] or coords[5] != [[], [], 'N']:
        cross_chamberness += 1

    # print(coords[0])
    # print(coords[1])
    # print(coords[2])
    # print(coords[3])
    # print(coords[4])
    # print(coords[5])
    # print(cross_chamberness)

    if cross_chamberness < 2:
        #print("Failed to reconstruct, too few chambers")
        return None

    #ITERATING OVER EVERY POSSIBLE COMBINATION OF x,y,z over all 3 RPCs (limited to one x,y per RPC).
    #Doesn't look particularly nice, but there are not many coordinates to loop over usually....

    combinations = generate_hit_coords_combo_Chi2(coords,RPC_heights, max_length=max_length, exact_length=exact_length)

    #Now for each combo in combinations, attempt to reconstruct a path. See which one gives the best trajectory.

    #If success, print parameters of fitting function.
    #If fail, print reconstruction failed.

    Chi2_current = np.inf
    optimised_coords = None
    optimised_d= None
    optimised_centroid= None
    dT = np.inf

    for ind,combo in enumerate(combinations):

        centroid, d, Chi2, coordinates, delta_T, delta_Z= fit_event_chi2(combo)
        if Chi2 < Chi2_current:

            # If new fit is better than old then replace old fit properties.
            dZ = delta_Z 
            dT = delta_T
            Chi2_current = Chi2
            optimised_centroid = centroid
            optimised_d = d
            optimised_coords = coordinates

    #if dT>0 this implies the particles hit the higher RPC after the lower one, so the particle is travelling upwards here.
    #Vice-versa for dT < 0.

    #dT = 0 case?
    
    if dT != np.inf:

        if dT > 0:
            if optimised_d[2] < 0:
                optimised_d = np.multiply(optimised_d,-1)
        else:
            if optimised_d[2] > 0:
                optimised_d = np.multiply(optimised_d,-1)

        if Chi2_current<max_Chi2:
            return optimised_centroid, optimised_d, optimised_coords, combinations, Chi2_current, dT, dZ

        else:
            #print("Failed to reconstruct, Chi2 too large")
            #return optimised_centroid, optimised_d, optimised_coords, combinations, residuals_current
            return None
def extract_angles_phi_eta_timed_DZ(filtered_events, max_length=None, exact_length=False):

    #Input is filtered_events, output of ANT.filter_events() function

    angles_eta = []
    angles_phi = []
    delta_times = []
    dZ = []
    chi2_values = []

    for i,filtered_event in enumerate(filtered_events):

        # print(f"Index= {i}") 
        
        result = reconstruct_timed_Chi2(filtered_event,3, max_length=max_length, exact_length=exact_length)

        if result is not None:

            delta_times.append(result[5])

            chi2_values.append(result[4])

            # if abs(result[5])>40:
            #     print(f"Index of abnormal event= {i}")
            # #Only save angles that actually were reconstructed well

            dZ.append(result[6])
            
            # a.b = |a||b|cos(x)

            #eta angle. 
            #work out the projection of the direction vector in the plane.
            
            v_parr_eta = np.array([0,result[1][1],result[1][2]])

            theta_eta = np.arccos(np.dot(v_parr_eta,[0,0,1]) / np.linalg.norm(v_parr_eta))

            if theta_eta > np.pi / 2:
                theta_eta= np.pi - theta_eta
            
            if v_parr_eta[1] > 0:
                theta_eta*=-1

            angles_eta.append(theta_eta)

            # Phi angles
            #work out the projection of the direction vector in the plane.
            
            v_parr_phi = np.array([result[1][0],0,result[1][2]])

            theta_phi = np.arccos(np.dot(v_parr_phi,[0,0,1]) / np.linalg.norm(v_parr_phi))

            if theta_phi > np.pi / 2:
                theta_phi= np.pi - theta_phi
            
            if v_parr_phi[0] < 0:
                theta_phi*=-1

            angles_phi.append(theta_phi)

    return angles_eta, angles_phi, delta_times, dZ, chi2_values
def interactive_muon_plot(centroid,d,event_coords):
    #Coefficients = [a,b,c]
    #event_coords = [[x0,y0,z0],[x1,y1,z1],...,[x5,y5,z5]]

    # Generate line coordinates
    t_values = np.linspace(-150, 150, 100)
    line_coordinates = centroid.reshape(-1, 1) + d.reshape(-1, 1) * t_values.reshape(1, -1)

    x_coords = [x[0] for x in event_coords]
    y_coords = [y[1] for y in event_coords]
    z_coords = [z[2] for z in event_coords]


    RPC_origins = [[0,0,0],[0,0,1.2],[0,0,2.4],[0,0,61.2],[0,0,121.2],[0,0,122.4]]
    RPC_dimensions = [180,99,1.2]

    #Calculate vertices for RPCs
    rpc_vertices = []
    for i in range(6):
        rpc_vertices.append(calculate_cuboid_vertices(RPC_origins[i],RPC_dimensions))

    # Configure Plotly to be rendered inline in the notebook.
    plotly.offline.init_notebook_mode()

    # Configure the trace for the RPCs
    rpc_0 = go.Mesh3d(
        x=[vertex[0] for vertex in rpc_vertices[0]],
        y=[vertex[1] for vertex in rpc_vertices[0]],
        z=[vertex[2] for vertex in rpc_vertices[0]],
        i=[0, 1, 2, 3, 0, 4, 5, 6, 7, 4, 5, 1, 2, 6, 7, 3],  # Indices for faces
        j=[1, 2, 3, 0, 4, 5, 6, 7, 5, 6, 2, 3, 7, 4, 0, 1],  # Indices for faces
        k=[2, 3, 0, 1, 6, 7, 4, 5, 1, 5, 6, 2, 3, 7, 4, 0],  # Indices for faces
        opacity=0.1,  # Set the opacity as needed
        color='green'  # Set the color of the cuboid
    )

    rpc_1 = go.Mesh3d(
        x=[vertex[0] for vertex in rpc_vertices[1]],
        y=[vertex[1] for vertex in rpc_vertices[1]],
        z=[vertex[2] for vertex in rpc_vertices[1]],
        i=[0, 1, 2, 3, 0, 4, 5, 6, 7, 4, 5, 1, 2, 6, 7, 3],  # Indices for faces
        j=[1, 2, 3, 0, 4, 5, 6, 7, 5, 6, 2, 3, 7, 4, 0, 1],  # Indices for faces
        k=[2, 3, 0, 1, 6, 7, 4, 5, 1, 5, 6, 2, 3, 7, 4, 0],  # Indices for faces
        opacity=0.1,  # Set the opacity as needed
        color='green'  # Set the color of the cuboid
    )

    rpc_2 = go.Mesh3d(
        x=[vertex[0] for vertex in rpc_vertices[2]],
        y=[vertex[1] for vertex in rpc_vertices[2]],
        z=[vertex[2] for vertex in rpc_vertices[2]],
        i=[0, 1, 2, 3, 0, 4, 5, 6, 7, 4, 5, 1, 2, 6, 7, 3],  # Indices for faces
        j=[1, 2, 3, 0, 4, 5, 6, 7, 5, 6, 2, 3, 7, 4, 0, 1],  # Indices for faces
        k=[2, 3, 0, 1, 6, 7, 4, 5, 1, 5, 6, 2, 3, 7, 4, 0],  # Indices for faces
        opacity=0.1,  # Set the opacity as needed
        color='green'  # Set the color of the cuboid
    )

    rpc_3 = go.Mesh3d(
        x=[vertex[0] for vertex in rpc_vertices[3]],
        y=[vertex[1] for vertex in rpc_vertices[3]],
        z=[vertex[2] for vertex in rpc_vertices[3]],
        i=[0, 1, 2, 3, 0, 4, 5, 6, 7, 4, 5, 1, 2, 6, 7, 3],  # Indices for faces
        j=[1, 2, 3, 0, 4, 5, 6, 7, 5, 6, 2, 3, 7, 4, 0, 1],  # Indices for faces
        k=[2, 3, 0, 1, 6, 7, 4, 5, 1, 5, 6, 2, 3, 7, 4, 0],  # Indices for faces
        opacity=0.1,  # Set the opacity as needed
        color='green'  # Set the color of the cuboid
    )

    rpc_4 = go.Mesh3d(
        x=[vertex[0] for vertex in rpc_vertices[4]],
        y=[vertex[1] for vertex in rpc_vertices[4]],
        z=[vertex[2] for vertex in rpc_vertices[4]],
        i=[0, 1, 2, 3, 0, 4, 5, 6, 7, 4, 5, 1, 2, 6, 7, 3],  # Indices for faces
        j=[1, 2, 3, 0, 4, 5, 6, 7, 5, 6, 2, 3, 7, 4, 0, 1],  # Indices for faces
        k=[2, 3, 0, 1, 6, 7, 4, 5, 1, 5, 6, 2, 3, 7, 4, 0],  # Indices for faces
        opacity=0.1,  # Set the opacity as needed
        color='green'  # Set the color of the cuboid
    )

    rpc_5 = go.Mesh3d(
        x=[vertex[0] for vertex in rpc_vertices[5]],
        y=[vertex[1] for vertex in rpc_vertices[5]],
        z=[vertex[2] for vertex in rpc_vertices[5]],
        i=[0, 1, 2, 3, 0, 4, 5, 6, 7, 4, 5, 1, 2, 6, 7, 3],  # Indices for faces
        j=[1, 2, 3, 0, 4, 5, 6, 7, 5, 6, 2, 3, 7, 4, 0, 1],  # Indices for faces
        k=[2, 3, 0, 1, 6, 7, 4, 5, 1, 5, 6, 2, 3, 7, 4, 0],  # Indices for faces
        opacity=0.1,  # Set the opacity as needed
        color='green'  # Set the color of the cuboid
    )

    # Configure the trace.
    trace = go.Scatter3d(
        x=x_coords,  # <-- Put your data instead
        y=y_coords,  # <-- Put your data instead
        z=z_coords, # <-- Put your data instead
        mode='markers',
        marker={
            'size': 10,
            'opacity': 1.0,
        }
    )

    #Plot zenith angle
    # zenith = go.Vector(...)

    # Extract x, y, z coordinates from line coordinates
    x_line = line_coordinates[0]
    y_line = line_coordinates[1]
    z_line = line_coordinates[2]
    
    # Configure the trace for the line
    trace_line = go.Scatter3d(
        x=x_line,
        y=y_line,
        z=z_line,
        mode='lines',
        line={
            'color': 'red',
            'width': 2,
        },
        name='Line'
    )

    trace_centroid = go.Scatter3d(
        x=[centroid[0]],
        y=[centroid[1]],
        z=[centroid[2]],
        mode='markers',
        marker={
            'size': 5,
            'color': 'green',
        },
        name='Centroid'
    )

    # Configure the layout.
    layout = go.Layout(
        margin={'l': 0, 'r': 0, 'b': 0, 't': 0},
        scene=dict(
            xaxis=dict(showgrid=True, gridcolor='rgb(211,211,211)', gridwidth=2,range=[-5,185], title = "x/cm"),
            yaxis=dict(showgrid=True, gridcolor='rgb(211,211,211)', gridwidth=2,range=[-5, 105],title = "y/cm"),
            zaxis=dict(showgrid=True, gridcolor='rgb(211,211,211)', gridwidth=2,range=[-5, 125],title="z/cm")
        )
    )

    #Include trace_centroid in data= [] to plot centroid on the plot.

    data = [trace,trace_line,rpc_0,rpc_1,rpc_2,rpc_3,rpc_4,rpc_5]

    plot_figure = go.Figure(data=data, layout=layout)

    # Render the plot.
    plotly.offline.iplot(plot_figure)
def calculate_cuboid_vertices(origin, dimensions):
    # Function to calculate vertices of cuboid from origin and dimensions
    x_min, y_min, z_min = origin
    x_max = x_min + dimensions[0]
    y_max = y_min + dimensions[1]
    z_max = z_min + dimensions[2]

    vertices = [
        [x_min, y_min, z_min], [x_max, y_min, z_min],
        [x_max, y_max, z_min], [x_min, y_max, z_min],
        [x_min, y_min, z_max], [x_max, y_min, z_max],
        [x_max, y_max, z_max], [x_min, y_max, z_max]
    ]

    return vertices
def find_tdc_alignment_metric(tdc0, tdc1):
    if tdc0 > tdc1:
        tdc0, tdc1 = tdc1, tdc0
    i, j, k, l = None, None, None, None
    if tdc0 == 0:
        if tdc1 == 1:
            i, j, k, l = 1, 2, 0, 1
        if tdc1 == 2:
            i, j, k, l = 3, 0, 3, 0
        if tdc1 == 3:
            i, j, k, l = 4, 0, 4, 0
        if tdc1 == 4:
            i, j, k, l = -1, -1, 5, 0
    if tdc0 == 1:
        if tdc1 == 2:
            i, j, k, l = 3, 2, 3, 1
        if tdc1 == 3:
            i, j, k, l = 5, 2, 4, 1
        if tdc1 == 4:
            i, j, k, l = -1, -1, 5, 1
    if tdc0 == 2:
        if tdc1 == 3:
            i, j, k, l = 4, 3, 4, 3
        if tdc1 == 4:
            i, j, k, l = -1, -1, 5, 3
    if tdc0 == 3:
        if tdc1 == 4:
            i, j, k, l = -1, -1, 5, 4
        
    return i, j, k, l
        
def get_element(i, j, data):
    if i == j:
        return None
    if i < j:
        return data.get((i, j), None)
    else:
        return data.get((j, i), None)    
#Reconstruction, with timing of RPC hit taken into account in trajectory.
def testAlign(rpc1Hits, rpc2Hits, skipChans = []):
    minTimes = [300,300]
    minChans = [-1,-1]
    if len(rpc1Hits)<1 or len(rpc2Hits)<1:
        return -1
    for hit in rpc1Hits:
        if hit.time<minTimes[0] and hit.channel not in skipChans:
            minTimes[0]=hit.time
            minChans[0]=hit.channel
    for hit in rpc2Hits:
        if hit.time<minTimes[1] and hit.channel not in skipChans:
            minTimes[1]=hit.time
            minChans[1]=hit.channel
    if -1 in minChans:
        return -1
    return abs(minChans[1]-minChans[0])
def count_entries(matrix):
    total_entries = 0
    for row in matrix:
        for cell in row:
            total_entries += len(cell)
    return total_entries
def calcAvgAlign(eventList,offSet=0, i = 1, j = 2, k = 0, l = 2, tdc1 =0, tdc0 = 1, processedEvents = 0, skipChans = []):
    mets = []
    for idx, event in enumerate(eventList):
        etaHits = [[] for rpc in range(6)]
        phiHits = [[] for rpc in range(6)]
        if (idx+abs(offSet))<len(eventList):
            if offSet<=0:
                oneIdx = idx+abs(offSet)
                twoIdx = idx
            else:
                oneIdx = idx
                twoIdx = idx+offSet
            for word in eventList[oneIdx].tdcEvents[tdc1].words:
                rpc, thisHit = tdcChanToRPCHit(word,tdc1, processedEvents + idx)
                if thisHit.eta:
                    etaHits[rpc].append(thisHit)
                # elif thisHit.eta == False and tdc1 == 2 and thisHit.channel < 31:
                #     continue
                else:
                    phiHits[rpc].append(thisHit)
            for word in eventList[twoIdx].tdcEvents[tdc0].words:
                rpc, thisHit = tdcChanToRPCHit(word,tdc0, processedEvents + idx)
                if thisHit.eta:
                    etaHits[rpc].append(thisHit)
                # elif thisHit.eta == False and tdc1 == 2 and thisHit.channel < 31:
                #     continue
                else:
                    phiHits[rpc].append(thisHit)
                       
            if i != -1:  
                etOff = testAlign(etaHits[i],etaHits[j], skipChans = skipChans)
                phOff = testAlign(phiHits[k],phiHits[l], skipChans = skipChans)
                if etOff>=0 and phOff>=0:
                    mets.append(math.sqrt(etOff*etOff+phOff*phOff))
            else:
                phOff = testAlign(phiHits[k],phiHits[l], skipChans = skipChans)
                if phOff>=0:
                    mets.append(math.sqrt(phOff*phOff))
    if len(mets)>0:
        return sum(mets)/len(mets)
    else:
        return 100
    
def doRealign(fReader, events, i=1, j=2, k=0, l=2, tdc1 = 0, tdc0 = 1, adjustment = 0, max_tdc = 4, processedEvents = 0, skipChans = []):
    aligned = True
    update = []
    # if i or j or k or l == None:
    #     return aligned, update
    alignMet = calcAvgAlign(events, offSet=0, i=i, j=j, k=k, l=l, tdc1 = tdc1, tdc0 = tdc0, skipChans = skipChans)
    if alignMet>18 and alignMet<100:
        aligned = False
        generated_list = [p for o in range(1, (4 + adjustment)) for p in (o, -o)]
        # generated_list.extend(range(95, 106))
        # generated_list.extend(range(-95, -106, -1))

        for testOffset in generated_list:
            testAlignMet = calcAvgAlign(events,testOffset, i=i, j=j, k=k, l=l, tdc1 = tdc1, tdc0 = tdc0, processedEvents=processedEvents, skipChans = skipChans)
            if testAlignMet<18:
                if testOffset>0:
                    for tdc in range(tdc1 + 1):
                        update.append(tdc)
                        for fakeEvent in range(testOffset):
                            fReader.evtBuilder.insertFakeEvent(tdc=tdc)
                else:
                    for tdc in range(max_tdc + 1):
                        if tdc >= tdc0:
                            update.append(tdc)
                            for fakeEvent in range(abs(testOffset)):
                                if tdc >= tdc0:
                                    fReader.evtBuilder.insertFakeEvent(tdc=tdc)
                                    
                aligned = True
                print("Found a new alignment, offsetting by",testOffset, "idx is", processedEvents, "updated TDC", update)
                break
    return aligned, update
def reconstruct_timed_Chi2_modified(event,max_cluster_size, max_length=None, exact_length=False):

    #timed tag indicates that timing information from RPC is used to determine direction of vertical transversal of "particle" in the event.

    max_Chi2 = 10

    # event = ['Event x',TIMEBIN, [[[RPC1_PHI_CLUSTERS],[RPC1_ETA_CLUSTERS]],[[...],[...]],...]
    RPC_heights = [0.6,1.8,3.0,61.8,121.8,123] #Heights of middle point of each RPC, measured from the bottom of the Triplet Low RPC. Units are cm.

    #Extract x and y coords of cluster in event

    coords = extract_coords_timed_Chi2(event,max_cluster_size)

    # Count the number of empty RPCs
    empty_RPC_count = sum(1 for item in coords if item == [[], [],'N'])

    # If less than 3 elements of coords are occupied, exit the function
    if empty_RPC_count > 3:
        #print("Failed to reconstruct, not enough coords")
        return None  # Exit the function
    
    #NEED TO CHECK IF STILL CROSS CHAMBER! 

    cross_chamberness = 0

    if coords[0] != [[], [], 'N'] or coords[1] != [[], [], 'N'] or coords[2] != [[], [], 'N']:
        cross_chamberness += 1

    if coords[3] != [[], [], 'N']:
        cross_chamberness += 1

    if coords[4] != [[], [], 'N'] or coords[5] != [[], [], 'N']:
        cross_chamberness += 1

    # print(coords[0])
    # print(coords[1])
    # print(coords[2])
    # print(coords[3])
    # print(coords[4])
    # print(coords[5])
    # print(cross_chamberness)

    # if cross_chamberness < 2:
    #     #print("Failed to reconstruct, too few chambers")
    #     return None

    #ITERATING OVER EVERY POSSIBLE COMBINATION OF x,y,z over all 3 RPCs (limited to one x,y per RPC).
    #Doesn't look particularly nice, but there are not many coordinates to loop over usually....

    combinations = generate_hit_coords_combo_Chi2(coords,RPC_heights, max_length=max_length, exact_length=exact_length)

    #Now for each combo in combinations, attempt to reconstruct a path. See which one gives the best trajectory.

    #If success, print parameters of fitting function.
    #If fail, print reconstruction failed.

    Chi2_current = np.inf
    optimised_coords = None
    optimised_d= None
    optimised_centroid= None
    dT = np.inf

    for ind,combo in enumerate(combinations):

        centroid, d, Chi2, coordinates, delta_T, delta_Z= fit_event_chi2(combo)
        if Chi2 < Chi2_current:

            # If new fit is better than old then replace old fit properties.
            dZ = delta_Z 
            dT = delta_T
            Chi2_current = Chi2
            optimised_centroid = centroid
            optimised_d = d
            optimised_coords = coordinates

    #if dT>0 this implies the particles hit the higher RPC after the lower one, so the particle is travelling upwards here.
    #Vice-versa for dT < 0.

    #dT = 0 case?
    
    if dT != np.inf:
        
        if optimised_d[2] > 0:
            optimised_d = np.multiply(optimised_d,-1)

        if Chi2_current<max_Chi2:
            return optimised_centroid, optimised_d, optimised_coords, combinations, Chi2_current, dT, dZ

        else:
            #print("Failed to reconstruct, Chi2 too large")
            #return optimised_centroid, optimised_d, optimised_coords, combinations, residuals_current
            return None
def extract_angles_phi_eta_timed_DZ_modified(filtered_events, max_length=None, exact_length=False):

    #Input is filtered_events, output of ANT.filter_events() function

    angles_eta = []
    angles_phi = []
    delta_times = []
    dZ = []
    chi2_values = []

    for i,filtered_event in enumerate(filtered_events):

        # print(f"Index= {i}") 
        
        result = reconstruct_timed_Chi2_modified(filtered_event,3 , max_length=max_length, exact_length=exact_length)

        if result is not None:

            delta_times.append(result[5])

            chi2_values.append(result[4])

            # if abs(result[5])>40:
            #     print(f"Index of abnormal event= {i}")
            #Only save angles that actually were reconstructed well

            dZ.append(result[6])
            
            # a.b = |a||b|cos(x)

            #eta angle. 
            #work out the projection of the direction vector in the plane.
            
            v_parr_eta = np.array([0,result[1][1],result[1][2]])

            theta_eta = np.arccos(np.dot(v_parr_eta,[0,0,1]) / np.linalg.norm(v_parr_eta))

            if theta_eta > np.pi / 2:
                theta_eta= np.pi - theta_eta
            
            if v_parr_eta[1] > 0:
                theta_eta*=-1

            angles_eta.append(theta_eta)

            # Phi angles
            #work out the projection of the direction vector in the plane.
            
            v_parr_phi = np.array([result[1][0],0,result[1][2]])

            theta_phi = np.arccos(np.dot(v_parr_phi,[0,0,1]) / np.linalg.norm(v_parr_phi))

            if theta_phi > np.pi / 2:
                theta_phi= np.pi - theta_phi
            
            if v_parr_phi[0] < 0:
                theta_phi*=-1

            angles_phi.append(theta_phi)

    return angles_eta, angles_phi, delta_times, dZ, chi2_values
def does_muon_hit_RPC(optimised_centroid, optimised_d, RPC):

    RPC_heights = [0.6,1.8,3.0,61.8,121.8,123] 
    #Heights of middle point of each RPC, measured from the bottom of the Triplet Low RPC. Units are cm.

    # x_bar = x_centroid + d_vector * t
    # Find value of paramter t when the muon trajectory passes through the RPC height.
    
    z_0 = optimised_centroid[2]
    z = RPC_heights[RPC]

    # t = (z-z_0)/d_z

    t = (z-z_0)/optimised_d[2]

    # Find expected (x,y) coordinates at that height.

    x = optimised_centroid[0] + t*optimised_d[0]
    y = optimised_centroid[1] + t*optimised_d[1]

    # Check if these (x,y) coordinates lie within the RPC. 

    #Extract x and y coords of cluster in event
    distance_per_phi_channel = 2.7625 #cm
    distance_per_eta_channel = 2.9844 #cm

    # Max y (eta side) is 31.5 * distance_per_eta_channel
    # Max x (phi side) is 63.5 * distance_per_phi_channel

    if 0 < x < 63.5*distance_per_phi_channel and 0 < y < 31.5*distance_per_eta_channel:
        #Return coordinates where you expect the muon to hit this RPC from the reconstructed event.
        return [x,y]
    else:
        #print("Muon does not hit RPC")
        return None    
def does_RPC_detect_muon(muon_coords,test_coords,tol):
    #Tolerance in units of cm. 

    #Could experiment with tolerance.

    if test_coords != [[],[],"N"]: 

        x_coords = test_coords[0]
        y_coords = test_coords[1]

        for x_set in x_coords:
            for y_set in y_coords:

                x = x_set[0]
                y = y_set[0]
    
                #If statement ensures only calculate the coords if the test_coords actually exist.

                #Offset is 2D vector that represents difference 
                offset = np.subtract(np.array([x,y]),muon_coords)

                separation = np.linalg.norm(offset)

                #print(separation)

                if separation <= tol:
                    #Say the RPC only successfully reconstructs an event 
                    #if the distance between expected hit and reconstructed hit is less than tolerance.

                    #print("RPC successfully detects hit!")
                    return separation
        
        #print("No RPC coordinates constructed pass near the expected point!")
        return False

    else:
        #print("No coordinates reconstructed by RPC")
        return False       
def calc_efficiency_RPC(dataset, RPC, tol):
    # Ensure RPC is a list, even if it's a single integer
    RPC_excluded = RPC

    # events = filter_events_by_RPC(dataset, 2, 5, RPC_excluded)
    datas = dataset

    possible_reconstructions = 0
    successful_reconstructions = [0 for i in range(len(tol))]

    for i, data in enumerate(datas):

        # print(f"Event index {i}")

        E_recon = reconstruct_timed_Chi2_ByRPC(data, 3, RPC_excluded)

        if E_recon:
            if len(E_recon[2]) >= 5:
                # Adding this check to see if other 5 RPCs are in reconstructed event.
                # This is necessary to ensure the reconstructed path is accurate.

                muon_coords = does_muon_hit_RPC(E_recon[0], E_recon[1], RPC_excluded)

                if muon_coords:
                    possible_reconstructions += 1
                    for idx, t in enumerate(tol):
                        check = does_RPC_detect_muon(muon_coords, E_recon[7], t)
                        if check:
                            successful_reconstructions[idx] += 1

    # print(possible_reconstructions)
    # print(successful_reconstructions)
    # if possible_reconstructions == 0:
    #     return -1
    # print(possible_reconstructions)
    # print(successful_reconstructions)

    if possible_reconstructions == 0:
        return -1
    return [i / possible_reconstructions for i in successful_reconstructions]

# %%
def tdcEventToRPCData(event,activeTDCs=[0,1,2,3,4], event_num = 0):
    rpcHits = [[] for rpc in range(6)]
    for tdc in activeTDCs:
        for word in event.tdcEvents[tdc].words:
            rpc, thisHit = tdcChanToRPCHit(word,tdc, event_num=event_num)
            rpcHits[rpc].append(thisHit)
    return rpcHits

# %%
importlib.reload(rawFileReader)
interval = 100
file_path = '../Data/Old/Beam2.raw'
fReader = rawFileReader.fileReader(file_path)
processedEvents = 0
events = []

flagged = []
flagged2 = []
values = [0, 1, 2, 3]
order0 = [[0, 1], [1, 2], [2, 4], [0,0]]
order1 = [[0,1], [1,2], [2,3], [3,4]]
alignment_event = [[] for item in order0]
lastWasBad = [False for i in range(len(order0))]
adjustment = [0 for i in range(len(order0))]
# aligned = True
alignevt = [[[], [], [], [], []] for _ in range(5)]
alignment_counter = 0
skip_chunk = 0
lasttdc3Status = False
tdc3Status = True
tdc3time = []
tdc3_alive_interval = 5000

temp = []
temp2 = []


while processedEvents<1000000:
    if not fReader.readBlock():
        print("Bad Block Read")
        break
    if(fReader.hasEvents()):
        for event in fReader.getEvents():
            events.append(event)
            processedEvents = processedEvents+1
            aligned_check = []
            if processedEvents%tdc3_alive_interval == 0 and processedEvents:
                poor_time = [0 for _ in range(tdc3_alive_interval)]
                for i, event in enumerate(events[-tdc3_alive_interval:]):
                    words = event.tdcEvents[3].words
                    times = [word & 0xfffff for word in words if (word >> 24) & 0x7f !=0]
                    tdc3time.extend(times)
                    poor_time[i] = sum(1 for t in times if t > 700)
                total_poor_time = sum(poor_time)
                # if processedEvents < 100000:
                #     temp.append(total_poor_time)
                # if processedEvents > 250000 and processedEvents < 350000:
                #     temp2.append(total_poor_time)
                if total_poor_time > 3800:
                    tdc3Status = False
                    if lasttdc3Status == True:
                        print('tdc3 is dead')
                        lasttdc3Status = False
                else:
                    tdc3Status = True
                    if lasttdc3Status == False:
                        print('tdc3 is alive')
                        lasttdc3Status = True
            
            if processedEvents%interval==0 and processedEvents>0:
                if tdc3Status == True:
                    order = order1
                else:
                    order = order0                
                for idx, item in enumerate(order):
                    i, j = item
                    if i + j != 0:
                        x, y, l, m = find_tdc_alignment_metric(i, j)
                        aligned, update = doRealign(fReader, events[-interval:], x, y, l, m, i, j, adjustment=adjustment[idx], processedEvents=processedEvents, skipChans = [0])
                        # aligned, update = True, []
                        # if update != []:
                        #     flagged2.append(processedEvents)
                        if update != []:
                            alignment_event[idx].append(processedEvents)
                        
                        aligned_check.append(aligned)
                        #If the last one was bad, and this one is also bad, then you increase your search region of that particular pauir by 2.
                        #I it is now aligned then change the adjustment back to 0
                        if lastWasBad[idx] and not aligned_check[idx]:
                            adjustment[idx] += 1
                        elif not aligned_check[idx]:
                            lastWasBad[idx] = True
                        else:
                            lastWasBad[idx] = False
                            adjustment[idx] = 0
# Out:
# Found a new alignment, offsetting by -2 idx is 100 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by -2 idx is 100 updated TDC [2, 3, 4]
# Found a new alignment, offsetting by -3 idx is 100 updated TDC [3, 4]
# Found a new alignment, offsetting by -2 idx is 100 updated TDC [4]
# tdc3 is alive
# Found a new alignment, offsetting by 3 idx is 20900 updated TDC [0]
# Found a new alignment, offsetting by -3 idx is 20900 updated TDC [2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 42000 updated TDC [0, 1]
# Found a new alignment, offsetting by -1 idx is 42100 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 95100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 95100 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 2 idx is 95200 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 1 idx is 95300 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 2 idx is 95400 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 2 idx is 95500 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 1 idx is 95600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 95600 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 95700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 95800 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 95900 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -1 idx is 96000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 96200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 96300 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 1 idx is 96400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 96600 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 96700 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 96800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 97100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 97400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 97700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 97900 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 98000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 98000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 98200 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -1 idx is 98300 updated TDC [3, 4]
# Found a new alignment, offsetting by -2 idx is 98400 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 98500 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 112000 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 112000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 126300 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 126300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 132100 updated TDC [2, 3, 4]
# Found a new alignment, offsetting by -4 idx is 132400 updated TDC [2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 148100 updated TDC [0]
# Found a new alignment, offsetting by -1 idx is 150400 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 150400 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -1 idx is 182800 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 182800 updated TDC [0, 1, 2]
# tdc3 is dead
# Found a new alignment, offsetting by -1 idx is 196200 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 196200 updated TDC [0, 1, 2]
# tdc3 is alive
# Found a new alignment, offsetting by -5 idx is 205300 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by -1 idx is 225300 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 225300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 234900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 235000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 235200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 235200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 235500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 235500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 235700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 235800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 236000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 236000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 236200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 236200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 236400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 236500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 236700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 236900 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 237000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 237000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 237300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 237300 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 237500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 237500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 237700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 237800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 238000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 238000 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 238500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 238600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 238800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 238800 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 238900 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by -1 idx is 239000 updated TDC [3, 4]
# Found a new alignment, offsetting by 1 idx is 239200 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 1 idx is 239600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 239600 updated TDC [4]
# tdc3 is dead
# Found a new alignment, offsetting by 1 idx is 293900 updated TDC [0]
# Found a new alignment, offsetting by 1 idx is 297700 updated TDC [0]
# Found a new alignment, offsetting by 1 idx is 299500 updated TDC [0]
# Found a new alignment, offsetting by 1 idx is 310700 updated TDC [0]
# Found a new alignment, offsetting by 1 idx is 322800 updated TDC [0]
# Found a new alignment, offsetting by -1 idx is 326400 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 326400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 338100 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by -1 idx is 340000 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 340000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 359000 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 359000 updated TDC [0, 1, 2]
# tdc3 is alive
# Found a new alignment, offsetting by -2 idx is 360300 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 360600 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -7 idx is 360700 updated TDC [3, 4]
# Found a new alignment, offsetting by 2 idx is 360700 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 3 idx is 360800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 360800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 361000 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 1 idx is 361100 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -1 idx is 361200 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 361400 updated TDC [3, 4]
# Found a new alignment, offsetting by 3 idx is 361400 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -3 idx is 361500 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 361800 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 361900 updated TDC [3, 4]
# Found a new alignment, offsetting by 2 idx is 362000 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -1 idx is 362100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 362200 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -3 idx is 362300 updated TDC [3, 4]
# Found a new alignment, offsetting by 1 idx is 362300 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 2 idx is 362700 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -2 idx is 362800 updated TDC [3, 4]
# Found a new alignment, offsetting by 1 idx is 362900 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -2 idx is 363300 updated TDC [3, 4]
# Found a new alignment, offsetting by -3 idx is 363300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 363400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 363400 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 1 idx is 363500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 363600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 363600 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 363700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 363800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 363900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 363900 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 1 idx is 364000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 364100 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -3 idx is 364300 updated TDC [3, 4]
# Found a new alignment, offsetting by 1 idx is 364300 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -3 idx is 364500 updated TDC [4]
# Found a new alignment, offsetting by 5 idx is 364700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 364800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 364800 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 2 idx is 364900 updated TDC [0, 1, 2]
# tdc3 is dead
# Found a new alignment, offsetting by -1 idx is 365200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 365400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 365500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 365600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 365800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 365900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 366200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 366500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 366700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 367000 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 367100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 367300 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 367400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 367700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 368200 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 368400 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 368500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 368900 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 369200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 369400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 369500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 370000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 370300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 370500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 370700 updated TDC [4]
# Found a new alignment, offsetting by 4 idx is 371000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 371100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 371500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 371600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 371800 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 371900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 372000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 372400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 372500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 372600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 373200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 373600 updated TDC [4]
# Found a new alignment, offsetting by -4 idx is 373900 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 374100 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 374200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 374700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 374900 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 375000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 375400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 375600 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 375700 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 375800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 376000 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 376700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 377000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 377200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 377500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 377600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 377700 updated TDC [4]
# Found a new alignment, offsetting by 4 idx is 378000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 378100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 378400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 378900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 379200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 379500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 379600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 380000 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 380100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 380300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 380400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 380600 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 380700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 380800 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 380900 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 381200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 381400 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 381500 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 381600 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 381700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 5 idx is 382300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 382700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 382900 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 383200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 383400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 383800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 384000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 384100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 384200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 384300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 384400 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 384700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 384800 updated TDC [0, 1, 2]
# tdc3 is alive
# Found a new alignment, offsetting by 3 idx is 385200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 385200 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 3 idx is 385400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 385500 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 385600 updated TDC [3, 4]
# Found a new alignment, offsetting by -1 idx is 385700 updated TDC [4]
# Found a new alignment, offsetting by -5 idx is 386000 updated TDC [3, 4]
# Found a new alignment, offsetting by 1 idx is 386000 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 1 idx is 386100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 386100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 386200 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -1 idx is 386300 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by -1 idx is 386300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 386500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 386700 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 386800 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 3 idx is 386900 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 5 idx is 387200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 387300 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 387500 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 387700 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -2 idx is 387800 updated TDC [3, 4]
# Found a new alignment, offsetting by -2 idx is 387900 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 388000 updated TDC [3, 4]
# Found a new alignment, offsetting by -2 idx is 388000 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 388100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 388200 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 3 idx is 388300 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 2 idx is 388400 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 3 idx is 388500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 388500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 388600 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -1 idx is 388900 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 389000 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by -6 idx is 389100 updated TDC [3, 4]
# Found a new alignment, offsetting by 2 idx is 389100 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 3 idx is 389200 updated TDC [0, 1, 2, 3]
# Found a new alignment, offsetting by 3 idx is 389300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 389300 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 389600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 389900 updated TDC [0, 1, 2, 3]
# tdc3 is dead
# Found a new alignment, offsetting by -1 idx is 390000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 390500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 390700 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 390800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 391100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 391400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 391600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 391700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 391800 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 392200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 392400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 392500 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 392600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 392900 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 393300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 393400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 393500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 393600 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 393700 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 393800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 394600 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 394700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 394900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 395000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 395100 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 395200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 395300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 395400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 395500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 395700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 396100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 396400 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 396500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 396800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 396900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 397000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 397100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 397200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 397300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 397600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 397800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 398000 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 398100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 398200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 398700 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 399100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 399300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 399500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 399700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 399800 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 2 idx is 400200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 400500 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 400600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 400700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 401200 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 401300 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 401400 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 401500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 401600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 401700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 401800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 401900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 402000 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 402100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 402400 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 402500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 403000 updated TDC [4]
# Found a new alignment, offsetting by 4 idx is 403400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 403700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 404100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 404400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 404700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 405300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 405400 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 405500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 405600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 405700 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 405800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 405900 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 406700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 406800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 407400 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 407500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 407800 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 408300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 408400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 408500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 408900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 409000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 409200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 409300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 410000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 410200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 410600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 410700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 410800 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 411000 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 411500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 411600 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 412100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 412300 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 412500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 412800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 413000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 413100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 413300 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 413500 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 413600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 414200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 414300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 414800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 414900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 415000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 415100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 415400 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 415600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 415800 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 416200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 416300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 416500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 416800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 417100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 417200 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 417500 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 417500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 417800 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 417900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 418000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 418300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 418400 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 418500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 418600 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 418700 updated TDC [4]
# Found a new alignment, offsetting by 4 idx is 419100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 419600 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 419700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 419900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 420100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 420400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 420500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 420600 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 420700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 420800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 420900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 421200 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 421400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 421600 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 421700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 421800 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 422000 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 422400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 422500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 422600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 422700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 422800 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 423000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 423400 updated TDC [4]
# Found a new alignment, offsetting by -4 idx is 423700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 424100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 424200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 424300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 424400 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 424600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 424700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 424800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 425000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 425500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 425600 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 425800 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by -2 idx is 425800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 426000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 426100 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by -1 idx is 426200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 426600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 426700 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 3 idx is 426700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 427100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 427200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 427300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 427500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 427700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 428000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 428200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 428300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 428400 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 428800 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 429000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 429200 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 429300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 429800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 430500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 430900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 431100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 431200 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 431300 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 431700 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 431800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 432000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 432100 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 432400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 432500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 432600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 433000 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 433400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 433500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 433900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 434000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 434100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 434300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 434400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 434600 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 434700 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 434900 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 435000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 435200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 435300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 435400 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 435500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 435600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 435700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 436100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 436300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 436400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 436500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 436600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 436700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 436800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 436900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 437100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 437300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 437400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 437700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 438100 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 438200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 438300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 438500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 438800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 439100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 439500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 439600 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 439800 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 439900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 440100 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 440500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 440600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 441000 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 441300 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 441500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 441600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 441900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 442000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 442900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 443200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 443300 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 443700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 443800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 444000 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 444100 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 444300 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 444700 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 445200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 445300 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 445400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 445500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 445600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 445700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 445800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 446000 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 446100 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 446200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 446800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 447000 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 447400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 447500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 448000 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 448600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 449000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 449300 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 449500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 449800 updated TDC [4]
# Found a new alignment, offsetting by -4 idx is 450200 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 450500 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 450700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 451000 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 451100 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by -3 idx is 451100 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 451300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 451400 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 451500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 452500 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 452600 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 452800 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 452900 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 453100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 453300 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 453400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 453600 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 453800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 453900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 454200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 454300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 454500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 454600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 455300 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 455400 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 455600 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 2 idx is 455700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 456000 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 456500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 456800 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 456900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 457000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 457200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 457400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 457500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 457700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 457800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 458000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 458400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 458500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 458600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 458700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 458900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 459000 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 459200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 459300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 459400 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 459600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 459700 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 460100 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 460200 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 460300 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 460900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 461100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 461300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 461600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 461700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 461800 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 462100 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 462200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 462400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 462600 updated TDC [4]
# Found a new alignment, offsetting by -4 idx is 463100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 463400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 463600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 464400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 464500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 464800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 465000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 465400 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 465500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 465900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 466200 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 466400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 466500 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 466600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 466700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 467100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 467500 updated TDC [4]
# Found a new alignment, offsetting by -4 idx is 467900 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 468000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 468200 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 468600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 468800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 468900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 469100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 469200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 469300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 469600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 469800 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 469900 updated TDC [4]
# Found a new alignment, offsetting by 5 idx is 470600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 470700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 470800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 470900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 471400 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 472300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 472700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 472900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 473100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 473200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 473300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 474000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 474100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 474400 updated TDC [0, 1, 2]
# ...
# Found a new alignment, offsetting by 1 idx is 947700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 947800 updated TDC [4]
# Found a new alignment, offsetting by 4 idx is 948100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 948200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 948500 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 948600 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 948900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 949100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 949200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 949300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 949400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 949500 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 950200 updated TDC [4]
# Found a new alignment, offsetting by -5 idx is 951000 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 951100 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 951300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 951400 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 951700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 951800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 952200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 952600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 952700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 952900 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 953300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 954000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 954100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 954300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 954400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 954900 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 955100 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 955300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 955400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 955500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 955700 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 955800 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 956100 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 956800 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 957000 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 957500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 957800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 958200 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 958400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 958500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 958600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 958800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 959100 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 959400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 959500 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 959700 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 959800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 959900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 960200 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 960300 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 960400 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 960500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 960700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 961100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 961500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 961900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 962500 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 962700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 962800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 962900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 963200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 963300 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 963500 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 963700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 963900 updated TDC [4]
# Found a new alignment, offsetting by 4 idx is 964300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 964700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 964800 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 965000 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 965300 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 965400 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 965600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 965700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 965800 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 966100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 966300 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 966400 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 966600 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 966700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 967100 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 967300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 967400 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 967800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 967900 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 968100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 968200 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 968300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 968400 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 968600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 968700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 968800 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 969100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 969500 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 969600 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 969900 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 970300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 970400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 971100 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 972100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 972200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 972300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 972700 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 972800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 973100 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 973300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 973500 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 973600 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 973800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 973900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 974600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 975000 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 975400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 975800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 976100 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 976200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 976300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 976700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 976800 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 977400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 977500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 977600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 977900 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 978100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 978400 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 978600 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 978900 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 979200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 979300 updated TDC [4]
# Found a new alignment, offsetting by 6 idx is 979900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 980400 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 980500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 980700 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 980800 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 981000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 981100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 981200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 981400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 981700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 981800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 981900 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 982100 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 982200 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 982400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 982700 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 983300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 983800 updated TDC [4]
# Found a new alignment, offsetting by -4 idx is 984100 updated TDC [4]
# Found a new alignment, offsetting by 4 idx is 984500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 984600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 984900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 985100 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 985700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -4 idx is 986100 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 986500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 986700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 986800 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 987000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 987200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 987400 updated TDC [4]
# Found a new alignment, offsetting by -3 idx is 987900 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 988000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 988100 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 988200 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 988300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 988400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 988800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 988900 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 989200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 989300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 989400 updated TDC [4]
# Found a new alignment, offsetting by -2 idx is 989500 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 989600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 989700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 989900 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 990300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 990400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 990500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 990800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 990900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 991000 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 991300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 991400 updated TDC [4]
# Found a new alignment, offsetting by -4 idx is 992000 updated TDC [4]
# Found a new alignment, offsetting by 4 idx is 992400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 992800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 992900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 993200 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 993400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 993500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 993900 updated TDC [1, 2, 3, 4]
# Found a new alignment, offsetting by 1 idx is 993900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 994300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 994400 updated TDC [4]
# Found a new alignment, offsetting by 6 idx is 994900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 4 idx is 995200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 995300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 995400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 995500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 995600 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 995700 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 996100 updated TDC [4]
# Found a new alignment, offsetting by 3 idx is 996300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 996400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 996600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -3 idx is 996800 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 997900 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 2 idx is 998200 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 998300 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 998500 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 1 idx is 998600 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -1 idx is 998800 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 998900 updated TDC [4]
# Found a new alignment, offsetting by -1 idx is 999300 updated TDC [4]
# Found a new alignment, offsetting by 2 idx is 999400 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by -2 idx is 999700 updated TDC [4]
# Found a new alignment, offsetting by 1 idx is 999800 updated TDC [0, 1, 2]
# Found a new alignment, offsetting by 3 idx is 999900 updated TDC [0, 1, 2]

# %%
plt.hist(temp, bins=10, edgecolor='black', label = 'good', alpha = 0.5)
plt.hist(temp2, bins=10, label = 'bad', alpha = 0.5)

plt.title('hittime good region for 5000 intervals')
plt.xlabel('hittime')
plt.ylabel('events')
plt.legend()

plt.show()

# %%
data = {}
order = [[0, 1], [1,2],[2,3], [3, 4], [2,4]]
# for i in values:
#     for j in values:
#         if i < j:
for item in order:
    i, j = item
    offsetTest = []
    for offSet in range(1):
        offsetTest.append([])
        print(offSet)
        for idx, event in enumerate(events):
            etaHits = [[] for rpc in range(6)]
            phiHits = [[] for rpc in range(6)]
            if (idx+offSet)<len(events):
                if offSet>25:
                    oneIdx = idx+offSet-25
                    twoIdx = idx
                else:
                    oneIdx = idx
                    twoIdx = idx+offSet
                for word in events[oneIdx].tdcEvents[i].words:
                    rpc, thisHit = tdcChanToRPCHit(word,i, idx)
                    if thisHit.eta:
                        etaHits[thisHit.rpc].append(thisHit)
                    else:
                        phiHits[thisHit.rpc].append(thisHit)
                for word in events[twoIdx].tdcEvents[j].words:
                    rpc, thisHit = tdcChanToRPCHit(word,j, idx)
                    if thisHit.eta:
                        etaHits[thisHit.rpc].append(thisHit)
                    else:
                        phiHits[thisHit.rpc].append(thisHit)
                x, y, l, m = find_tdc_alignment_metric(i, j)
                if x != -1:    
                    etOff = testAlign(etaHits[x],etaHits[y])
                    phOff = testAlign(phiHits[l],phiHits[m])
                    Metric = etOff*etOff+phOff*phOff
                    if etOff>=0 and phOff>=0:
                        offsetTest[-1].append(math.sqrt(Metric))
                    else:
                        offsetTest[-1].append(-1)
                else:
                    phOff = testAlign(phiHits[l],phiHits[m])
                    Metric = phOff*phOff
                    if phOff>=0:
                        offsetTest[-1].append(math.sqrt(Metric))
                    else:
                        offsetTest[-1].append(-1)
    binsx = [x*interval for x in range(10001)]
    noffs = 1
    offsets = [[0 for xbin in binsx] for offset in range(noffs)]
    offsetOne = [0 for xbin in binsx]
    for testOff in range(noffs):
        xbin=0
        counts=0
        for idx, offset in enumerate(offsetTest[testOff]):
            if offset>-0.5:
                offsets[testOff][xbin]=offsets[testOff][xbin]+offset
                counts = counts+1
            if idx%interval==0 and idx>0:
                if counts>0:
                    offsets[testOff][xbin]=offsets[testOff][xbin]/counts
                xbin=xbin+1
                counts=0
        if counts>0:
            offsets[testOff][xbin]=offsets[testOff][xbin]/counts
    data[(i, j)] = [offsets, binsx]
    
    
fig, ax = plt.subplots(figsize=(10, 8))
# for i in values:
#     for j in values:
#         if i < j:
for item in order:
    i, j = item
    offsets, binsx = get_element(i,j, data)
    for idx, offsethist in enumerate(offsets):
        if idx <1:
            ax.plot(binsx,offsethist,label=f'TDC{i} and TDC{j}, offset{idx}')
    
            # plotted_tdc2 = False
            # plotted_tdc1 = False
            # for x in alignevt[2][1]:
            #     if not plotted_tdc2:
            #         ax.axvline(x=x, color='r', linestyle='--', label='TDC2')
            #         plotted_tdc2 = True
            #     else:
            #         ax.axvline(x=x, color='r', linestyle='--')
            # for x in alignevt[1][2]:
            #     if not plotted_tdc1:
            #         ax.axvline(x=x, color='b', linestyle='--', label='TDC1')
            #         plotted_tdc1 = True
            #     else:
            #         ax.axvline(x=x, color='b', linestyle='--')

ax.set_xlim(0,1000000)
ax.set_ylim(0,40)
ax.legend()
ax.set_title('Alignment attempted clever adjustment used')
ax.set_ylabel('Average $\sqrt{d\eta^2+d\phi^2}$')
ax.set_xlabel('Event')
plt.show()
# Out:
# <>:101: SyntaxWarning: invalid escape sequence '\s'
# <>:101: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Peter\AppData\Local\Temp\ipykernel_11328\849490004.py:101: SyntaxWarning: invalid escape sequence '\s'
#   ax.set_ylabel('Average $\sqrt{d\eta^2+d\phi^2}$')
# 0
# 0
# 0
# 0
# 0

# %%
def readTDCTimeDiffs(filename, Events):
    totDiffs = {0:[[0 for etchan in range(32)] for phchan in range(64)],
                1:[[0 for etchan in range(32)] for phchan in range(64)], 
                2:[[0 for etchan in range(32)] for phchan in range(64)], 
                3:[[0 for etchan in range(32)] for phchan in range(64)],
                4:[[0 for etchan in range(32)] for phchan in range(64)],
                5:[[0 for etchan in range(32)] for phchan in range(64)]}
    nDiffs = {0:[[0 for etchan in range(32)] for phchan in range(64)],
                1:[[0 for etchan in range(32)] for phchan in range(64)], 
                2:[[0 for etchan in range(32)] for phchan in range(64)], 
                3:[[0 for etchan in range(32)] for phchan in range(64)],
                4:[[0 for etchan in range(32)] for phchan in range(64)],
                5:[[0 for etchan in range(32)] for phchan in range(64)]}
    diffHists = {0:[[hi.Hist(hi.axis.Regular(bins=376, start=-150.4, stop=150.4, name="rpc0etPhiDiff")) for etchan in range(32)] for phchan in range(64)],
                 1:[[hi.Hist(hi.axis.Regular(bins=376, start=-150.4, stop=150.4, name="rpc1etPhiDiff")) for etchan in range(32)] for phchan in range(64)],
                 2:[[hi.Hist(hi.axis.Regular(bins=376, start=-150.4, stop=150.4, name="rpc2etPhiDiff")) for etchan in range(32)] for phchan in range(64)],
                 3:[[hi.Hist(hi.axis.Regular(bins=376, start=-150.4, stop=150.4, name="rpc3etPhiDiff")) for etchan in range(32)] for phchan in range(64)],
                 4:[[hi.Hist(hi.axis.Regular(bins=376, start=-150.4, stop=150.4, name="rpc4etPhiDiff")) for etchan in range(32)] for phchan in range(64)],
                 5:[[hi.Hist(hi.axis.Regular(bins=376, start=-150.4, stop=150.4, name="rpc5etPhiDiff")) for etchan in range(32)] for phchan in range(64)]}

    importlib.reload(rawFileReader)
    processedEvents = 0
    for idx, event in enumerate(Events):
        processedEvents = processedEvents+1
        if processedEvents%100000==0:
            print("Processed",processedEvents,"Events")
        rpcHits = tdcEventToRPCData(event,activeTDCs=[0,1,2,3,4], event_num=idx)
        for rpc in [0, 1, 2, 3, 4, 5]:
            minEtaHit = rpcHit(-1,1000,True, -1, -1)
            minPhiHit = rpcHit(-1,1000,False, -1, -1)
            for hit in rpcHits[rpc]:
                if hit.time>150 and hit.time<300:
                    if hit.eta and hit.time<minEtaHit.time:
                        minEtaHit = hit
                    elif hit.time<minPhiHit.time and not hit.eta:
                        minPhiHit = hit
            if minEtaHit.channel>-0.5 and minPhiHit.channel>-0.5:
                totDiffs[rpc][minPhiHit.channel][minEtaHit.channel] = totDiffs[rpc][minPhiHit.channel][minEtaHit.channel]+minEtaHit.time-minPhiHit.time
                nDiffs[rpc][minPhiHit.channel][minEtaHit.channel] = nDiffs[rpc][minPhiHit.channel][minEtaHit.channel]+1
                diffHists[rpc][minPhiHit.channel][minEtaHit.channel].fill(minEtaHit.time-minPhiHit.time)
    outDict = {'totDiffs':totDiffs,
               'nDiffs':nDiffs,
               'diffHists':diffHists}
    return outDict

# %%
readDict = readTDCTimeDiffs('..//Data//Old//Beam2.raw', events)
# Out:
# Processed 100000 Events
# Processed 200000 Events

# %%
print(readDict)
# Out:
# {'totDiffs': {0: [[779.2, 1005.5999999999999, 1240.0000000000005, 1189.6000000000001, 1915.1999999999987, 2987.9999999999964, 3311.2000000000016, 3594.4000000000005, 3586.3999999999987, 4056.799999999997, 3642.400000000004, 3731.9999999999995, 5211.199999999993, 4983.200000000001, 5408.0, 5831.200000000012, 5252.000000000005, 5709.600000000004, 5327.200000000001, 5444.8, 5068.8, 6214.400000000009, 5312.800000000003, 5474.400000000002, 6275.199999999998, 683.1999999999997, 5576.000000000006, 2503.999999999999, 687.1999999999999, 769.6000000000001, 340.0, 247.19999999999993], [589.6, 684.7999999999997, 769.6000000000001, 1198.4, 2072.0000000000014, 1930.3999999999996, 2446.4000000000024, 2789.6000000000035, 3155.1999999999994, 3049.6000000000013, 3533.6, 2882.399999999999, 3133.6, 3875.999999999994, 3334.4000000000005, 3445.6000000000045, 4216.000000000005, 3179.199999999997, 3365.599999999998, 4050.3999999999974, 3693.6000000000013, 3220.7999999999993, 3265.5999999999995, 3087.2000000000016, 3844.799999999999, 566.4000000000001, 4256.0, 2848.0000000000014, 258.4000000000001, 1238.3999999999999, 412.8, 38.400000000000006], [973.5999999999998, 1100.7999999999997, 1424.0, 2114.4000000000015, 3868.799999999998, 4371.1999999999925, 4560.800000000001, 5104.8, 4963.199999999999, 6309.600000000007, 6050.399999999999, 4951.200000000003, 6531.999999999996, 7467.200000000003, 7648.799999999998, 6731.200000000019, 8092.8000000000175, 7018.400000000015, 6128.000000000001, 7171.200000000012, 5510.400000000001, 7041.600000000017, 6019.20000000001, 7883.199999999992, 8441.599999999997, 1396.0000000000014, 8351.999999999984, 5804.799999999995, 797.6000000000001, 2793.6000000000017, 441.60000000000014, 132.0], [1064.0000000000005, 868.8, 1068.8, 1474.400000000001, 2202.4000000000005, 2561.6000000000017, 3091.199999999997, 4469.599999999998, 3946.400000000003, 4784.799999999996, 4228.799999999996, 3767.9999999999936, 5506.399999999999, 4531.199999999997, 5656.799999999995, 4699.2, 5666.400000000011, 5582.400000000003, 4678.4000000000015, 4766.400000000003, 4420.800000000003, 5344.800000000001, 4616.800000000002, 5508.000000000002, 6010.399999999998, 1002.4000000000007, 6317.5999999999985, 5036.800000000003, 893.6, 2469.6000000000013, 409.59999999999974, 111.20000000000002], [1132.0, 963.9999999999997, 1553.6000000000004, 2029.6000000000006, 3392.800000000001, 3896.7999999999993, 4045.600000000001, 4649.599999999999, 4862.4, 5727.999999999999, 4963.999999999987, 4614.400000000004, 6886.399999999997, 5796.800000000002, 6405.6, 6872.000000000009, 6458.400000000011, 7038.400000000003, 5751.200000000006, 6584.000000000003, 6715.200000000007, 7153.600000000008, 6350.4000000000015, 7490.399999999994, 7185.5999999999985, 1403.2, 8135.200000000001, 5291.2, 1547.199999999999, 3687.199999999998, 593.5999999999997, 252.00000000000009], [739.2000000000004, 959.1999999999991, 1206.4000000000003, 1588.0, 2435.2000000000007, 3273.600000000001, 3104.7999999999965, 3801.6000000000017, 3751.2000000000025, 4671.199999999995, 4105.599999999998, 4096.799999999996, 5114.400000000006, 5995.2, 5661.599999999993, 5236.8000000000075, 5478.400000000003, 5598.4000000000015, 4695.2000000000035, 5214.400000000002, 5943.200000000019, 5761.600000000001, 4723.200000000002, 5579.2, 6230.400000000002, 1432.0, 6140.800000000001, 4584.799999999999, 1284.7999999999997, 3575.199999999999, 387.20000000000005, 224.00000000000003], [1055.9999999999995, 1334.4, 1596.0000000000005, 2343.9999999999995, 3621.6000000000013, 4451.199999999993, 4371.199999999993, 5200.0, 5200.000000000005, 5895.199999999999, 6504.799999999996, 5203.999999999999, 7300.000000000013, 6358.399999999994, 7148.800000000008, 7166.40000000001, 9168.800000000016, 8424.000000000011, 7424.000000000022, 8068.000000000021, 6536.000000000014, 7536.800000000017, 6759.200000000016, 8470.400000000009, 8768.80000000001, 4180.000000000001, 9823.999999999996, 7148.7999999999965, 1927.9999999999993, 5723.9999999999945, 1417.60000000 ...

# %%
scDiffs = [[0 for etchan in range(32)] for phchan in range(64)]
normDiffs = [[0 for etchan in range(32)] for phchan in range(64)]
badPhi = {0:[],1:[61, 63],2:[31], 3:[0],4:[0,19], 5:[0, 31]}
badEta = {0:[24,25,26,27,28,29,30,31],1:[11, 15],2:[],3:[31],4:[31], 5:[]}
residEtaLatest = []
residPhiLatest = []
rpcNames = {0:"Triplet Low",1: "Triplet Mid", 2:"Triplet Top", 3:"Singlet",4:"Doublet Low",5:"Doublet Top"}
evtCount = 0
for rpc in [0,1,2,3,4,5]:
    slope = 0.173
    offSet = 13.2
    for ph in range(64):
        for et in range(32):
            if sum(readDict['diffHists'][rpc][ph][et].counts())>0:
                scDiffs[ph][et]=sum([thisVal*readDict['diffHists'][rpc][ph][et].axes.centers[0][idx] for idx, thisVal in enumerate(readDict['diffHists'][rpc][ph][et])])/sum(readDict['diffHists'][rpc][ph][et].counts())
                normDiffs[ph][et]=scDiffs[ph][et]+slope*(ph-et)-offSet

    fig, ax = plt.subplots(1, figsize=(16, 8), dpi=100)
    etachannels = [x-0.5 for x in range(33)]
    phichannels = [x-0.5 for x in range(65)]
    etaHist = (scDiffs,np.array(phichannels),np.array(etachannels))
    zrange = [-5,30]
    thisHist = hep.hist2dplot(etaHist,norm=colors.Normalize(zrange[0],zrange[1]))
    thisHist.cbar.set_label('$\eta$ hit time - $\phi$ hit time, Average (ns)', rotation=270, y=0.3,labelpad=23)
    plt.ylim(31.5,-0.5)
    plt.ylabel("Eta Channel")
    plt.xlabel("Phi Channel")
    ax.set_title(rpcNames[rpc])
    x_points = [-0.5, 64.5]
    y_points = [7.5, 15.5, 23.5]
    for y_point in y_points:
        plt.plot(x_points, [y_point,y_point], 'k', linestyle='dotted')
    y_points = [-0.5, 31.5]
    x_points = [7.5,15.5, 23.5, 31.5, 39.5, 47.5, 55.5]
    for x_point in x_points:
        plt.plot([x_point,x_point], y_points, 'k', linestyle='dashed')
    plt.show()
    fig, ax = plt.subplots(1, figsize=(16, 8), dpi=100)
    normHist = (normDiffs,np.array(phichannels),np.array(etachannels))
    zrange = [-4,4]
    thisHist = hep.hist2dplot(normHist,norm=colors.Normalize(zrange[0],zrange[1]))
    thisHist.cbar.set_label('$\eta$ hit time - $\phi$ hit time, Average (ns)', rotation=270, y=0.3,labelpad=23)
    plt.ylim(31.5,-0.5)
    plt.ylabel("Eta Channel")
    plt.xlabel("Phi Channel")

    x_points = [-0.5, 64.5]
    y_points = [7.5, 15.5, 23.5]
    for y_point in y_points:
        plt.plot(x_points, [y_point,y_point], 'k', linestyle='dotted')
    y_points = [-0.5, 31.5]
    x_points = [7.5,15.5, 23.5, 31.5, 39.5, 47.5, 55.5]
    for x_point in x_points:
        plt.plot([x_point,x_point], y_points, 'k', linestyle='dashed')
    ax.set_title(rpcNames[rpc]+", Propagation Time Corrected")
    plt.show()
    phTimes = [0 for chan in range(64)]
    etTimes = [0 for chan in range(32)]
    testSpeed = 0.173
    offSet = 13.46
    for phchan in range(64):
        for etchan in range(32):
            if etchan not in badEta[rpc]:
                phTimes[phchan] = phTimes[phchan]+scDiffs[phchan][etchan]-etchan*testSpeed+phchan*testSpeed-offSet
        phTimes[phchan] = phTimes[phchan]/(32.-len(badEta[rpc]))
    for phchan in range(64):
        for etchan in range(32):
            if phchan not in badPhi[rpc]:
                etTimes[etchan] = etTimes[etchan]+(scDiffs[phchan][etchan]+phchan*testSpeed-etchan*testSpeed-offSet-phTimes[phchan])/(64.-len(badPhi[rpc]))
    residEtaLatest.append([time for time in etTimes])
    residPhiLatest.append([time for time in phTimes])
# Out:
# <>:24: SyntaxWarning: invalid escape sequence '\e'
# <>:42: SyntaxWarning: invalid escape sequence '\e'
# <>:24: SyntaxWarning: invalid escape sequence '\e'
# <>:42: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\Peter\AppData\Local\Temp\ipykernel_31508\906074379.py:24: SyntaxWarning: invalid escape sequence '\e'
#   thisHist.cbar.set_label('$\eta$ hit time - $\phi$ hit time, Average (ns)', rotation=270, y=0.3,labelpad=23)
# C:\Users\Peter\AppData\Local\Temp\ipykernel_31508\906074379.py:42: SyntaxWarning: invalid escape sequence '\e'
#   thisHist.cbar.set_label('$\eta$ hit time - $\phi$ hit time, Average (ns)', rotation=270, y=0.3,labelpad=23)
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None
# Warning: <class 'uhi.numpy_plottable.NumPyPlottableHistogram'> is not allowed to get flow bins, flow bin option set to None

# %%
print(residPhiLatest[2])
# Out:
# [np.float64(-0.22650970991411387), np.float64(-1.1036410735352258), np.float64(-0.611916785647718), np.float64(-0.9964405988038979), np.float64(-0.29377037483834534), np.float64(-0.8697086689525007), np.float64(-0.19987942059955058), np.float64(-1.6812806465616144), np.float64(-0.6646207069771091), np.float64(-0.9981761551120027), np.float64(-0.2373947952684591), np.float64(-1.3341991853880046), np.float64(-1.421987423212201), np.float64(-1.2284822354064866), np.float64(-1.1747519882398716), np.float64(-3.0051857038793313), np.float64(0.5894482209563604), np.float64(-0.3484497508375206), np.float64(0.6651116182575945), np.float64(-0.5918207876688898), np.float64(-0.45758483214365037), np.float64(-0.9163374375289282), np.float64(0.2781801363085757), np.float64(-1.2596094066659718), np.float64(0.0580358233775391), np.float64(-0.30021581039511586), np.float64(0.06272033626062339), np.float64(-1.122965776822116), np.float64(-1.7115101364129854), np.float64(-2.1258067589271428), np.float64(-1.0013260718430002), np.float64(-3.0645587053157626), np.float64(-0.625892380388369), np.float64(-1.6835614103947372), np.float64(-0.6277506432389356), np.float64(-1.4074329707602005), np.float64(-1.4251959976143478), np.float64(-1.6233661283406657), np.float64(-0.6970716134522497), np.float64(-1.6948253446771309), np.float64(0.017873207856820523), np.float64(-0.3949193262999929), np.float64(0.19631168874191474), np.float64(-0.39074811427807005), np.float64(-1.073515504853608), np.float64(-1.3823148174203412), np.float64(-0.7048590121164611), np.float64(-2.251030104953344), np.float64(-0.6809668442520072), np.float64(-1.4644656640549687), np.float64(-0.31543804259465885), np.float64(-1.3161355115720026), np.float64(-1.1024327143298331), np.float64(-0.3338674589423412), np.float64(0.1706337380710942), np.float64(-1.0220694293591441), np.float64(-0.21112445763690624), np.float64(-1.1182060337825874), np.float64(-0.17737606908039508), np.float64(-1.0771472285969284), np.float64(-1.122709724617449), np.float64(-1.1224736441940169), np.float64(-0.5116010205620494), np.float64(-3.3482900143210492)]

# %%
fig, ax = plt.subplots(1, figsize=(16, 8), dpi=100)
phichannels = [x-0.5 for x in range(65)]

for idx, rpc in enumerate([0, 1, 2, 3, 4, 5]):
    print(idx)
    plotPhiResids = residPhiLatest[idx].copy()
    plotPhiResids.append(plotPhiResids[-1])
    plt.step(phichannels,plotPhiResids,linewidth=3,label=rpcNames[rpc],where='post')
yrange = ax.get_ylim()
#ax.text(40, 0.8*yrange[1], "Slope: "+str(round(popt[0],3))+" ns/channel, Offset: "+str(round(popt[1],2))+" ns", fontsize=14,
 #               verticalalignment='top')
ax.set_xlabel('$\phi$ Channel')
ax.set_ylabel('Time Residual (ns)')
ax.set_ylim([-6,6])
ax.set_xlim([-0.5,63.5])
plt.legend()
plt.show()
fig, ax = plt.subplots(1, figsize=(16, 8), dpi=100)
etchannels = [x-0.5 for x in range(33)]
for idx, rpc in enumerate([0,1, 2, 3, 4, 5]):
    plotEtaResids = residEtaLatest[idx].copy()
    plotEtaResids.append(plotEtaResids[-1])
    plt.step(etchannels,plotEtaResids,linewidth=3,label=rpcNames[rpc],where='post')
yrange = ax.get_ylim()
#ax.text(40, 0.8*yrange[1], "Slope: "+str(round(popt[0],3))+" ns/channel, Offset: "+str(round(popt[1],2))+" ns", fontsize=14,
 #               verticalalignment='top')   
ax.set_xlabel('$\eta$ Channel')
ax.set_ylabel('Time Residual (ns)')
ax.set_ylim([-6,6])
ax.set_xlim([-0.5,31.5])
plt.legend()
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# <>:27: SyntaxWarning: invalid escape sequence '\e'
# <>:12: SyntaxWarning: invalid escape sequence '\p'
# <>:27: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\Peter\AppData\Local\Temp\ipykernel_31508\1867468360.py:12: SyntaxWarning: invalid escape sequence '\p'
#   ax.set_xlabel('$\phi$ Channel')
# C:\Users\Peter\AppData\Local\Temp\ipykernel_31508\1867468360.py:27: SyntaxWarning: invalid escape sequence '\e'
#   ax.set_xlabel('$\eta$ Channel')
# 0
# 1
# 2
# 3
# 4
# 5
